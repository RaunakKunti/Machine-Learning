# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('./carprices.csv')

# %%
df.isnull().sum()
# Out:
# Car Model        0
# Mileage          0
# Sell Price($)    0
# Age(yrs)         0
# dtype: int64

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
f = pd.get_dummies(df['Car Model']).astype(int)

# %%
f
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
con = pd.concat([df,f],axis='columns')

# %%
con
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0                  BMW X5    69000          18000         6        0       1                      0
# 1                  BMW X5    35000          34000         3        0       1                      0
# 2                  BMW X5    57000          26100         5        0       1                      0
# 3                  BMW X5    22500          40000         2        0       1                      0
# 4                  BMW X5    46000          31500         4        0       1                      0
# 5                 Audi A5    59000          29400         5        1       0                      0
# 6                 Audi A5    52000          32000         5        1       0                      0
# 7                 Audi A5    72000          19300         6        1       0                      0
# 8                 Audi A5    91000          12000         8        1       0                      0
# 9   Mercedez Benz C class    67000          22000         6        0       0                      1
# 10  Mercedez Benz C class    83000          20000         7        0       0                      1
# 11  Mercedez Benz C class    79000          21000         7        0       0                      1
# 12  Mercedez Benz C class    59000          33000         5        0       0                      1

# %%
final = con.drop(['Car Model'],axis='columns')

# %%
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000          18000         6        0       1                      0
# 1     35000          34000         3        0       1                      0
# 2     57000          26100         5        0       1                      0
# 3     22500          40000         2        0       1                      0
# 4     46000          31500         4        0       1                      0
# 5     59000          29400         5        1       0                      0
# 6     52000          32000         5        1       0                      0
# 7     72000          19300         6        1       0                      0
# 8     91000          12000         8        1       0                      0
# 9     67000          22000         6        0       0                      1
# 10    83000          20000         7        0       0                      1
# 11    79000          21000         7        0       0                      1
# 12    59000          33000         5        0       0                      1

# %%
final = final.drop(['Audi A5'],axis='columns')

# %%
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000          18000         6       1                      0
# 1     35000          34000         3       1                      0
# 2     57000          26100         5       1                      0
# 3     22500          40000         2       1                      0
# 4     46000          31500         4       1                      0
# 5     59000          29400         5       0                      0
# 6     52000          32000         5       0                      0
# 7     72000          19300         6       0                      0
# 8     91000          12000         8       0                      0
# 9     67000          22000         6       0                      1
# 10    83000          20000         7       0                      1
# 11    79000          21000         7       0                      1
# 12    59000          33000         5       0                      1

# %%
x = final.drop(['Sell Price($)'],axis='columns')

# %%
x
# Out:
#     Mileage  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000         6       1                      0
# 1     35000         3       1                      0
# 2     57000         5       1                      0
# 3     22500         2       1                      0
# 4     46000         4       1                      0
# 5     59000         5       0                      0
# 6     52000         5       0                      0
# 7     72000         6       0                      0
# 8     91000         8       0                      0
# 9     67000         6       0                      1
# 10    83000         7       0                      1
# 11    79000         7       0                      1
# 12    59000         5       0                      1

# %%
y = final['Sell Price($)']

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.9417050937281082

# %% [markdown]
# # Price of mercedez benz that is 4 yr old with mileage 45000

# %%
model.predict([[45000,4,0,1]])
# Out:
# C:\Users\a\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36991.31721061])

# %% [markdown]
# # Price of BMW X5 that is 7 yr old with mileage 86000

# %%
model.predict([[86000,7,1,0]])
# Out:
# C:\Users\a\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11080.74313219])
